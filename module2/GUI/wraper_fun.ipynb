# %%
def add(a, b):
    return a + b

# %%
def decorate(fun):
    def fun():
        return f'Addition of two numbers {a} and {b} is {a+b}'
    return fun(2, 4)

# %%
re = add(2, 4)
print(re)
# Out:
# 6

# %%
dec_fun = decorate(add)
re = dec_fun(2, 4)
print(re)
# Out:
# Addition of two numbers 2 and 4 is 6

# %%
def info(sub):
    print('GLA', sub)

# %%
(lambda :info('english'))()
# Out:
# GLA english

# %%
tp = (1,)

tp[0]
